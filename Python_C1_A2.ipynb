# %% [markdown]
# <a href="https://colab.research.google.com/github/MukRodrigues/Python-Calculo-I/blob/main/Python_C1_A2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **XVIII Semana do IME**

# %% [markdown]
# <img src="https://images.even3.com/OJopDZFuJnBgAuP-51IfsFjb2So=/1100x440/smart/https://static.even3.com/banner/faixaEVEN3XVIIISemanaDoIME.785c694863d74dd5ad33.png" width="1000">

# %% [markdown]
# <img src="https://www.uerj.br/wp-content/uploads/2018/02/logomarca-uerj.png" width="150">
#
#
#
# <img src="https://www.ime.uerj.br/wp-content/uploads/2021/08/ime-logo.png" width="350">
#
#
# <img src="https://ccomp.ime.uerj.br/wp-content/uploads/2024/10/Logo-CompMat-Home.png" width="250">

# %% [markdown]
# # **Cálculo 1 com Python**
#
# #### Inscrição: https://www.even3.com.br/xviii-semana-do-ime-622247/
#
#
# **Instrutor: Samuel Rodrigues**
#
#
# #### Lattes: https://lattes.cnpq.br/9400647055736707

# %% [markdown]
# ## **Aula 2**
#
# **Conteúdo da Aula 1**
#
# https://colab.research.google.com/drive/1KGTH9HXPOrgquMA7eTgU1wHzdrvIfHcN#scrollTo=QWm05-ny494J
#
# *  **Introdução:** o que é Python, declaração de variáveis numéricas e operações aritméticas;
#
# * **Aritmética básica:** declaração de variáveis e operações matemáticas;
#
# * **Funções matemáticas:** declaração de variáveis e funções (Sympy e Numpy), construção de gráficos de funções (Matplotlib).
#
#
# **Conteúdo da Aula 2**
#
# *  **Tópicos de Cálculo I:** limite, continuidade, derivação, integração;
#
# * **Aplicações**: uso das bibliotecas Sympy, Numpy e Matplotlib para resolução de problemas de Cálculo 1.
#
#
# **Referências:**
#
# * Guidorizzi, H. *Um curso de cálculo.* Vol I. - 5.ed.- Rio de Janeiro: LTC, 2013. ISBN 978-85-216-2244-4.
#
# * Carvalhaes, C. G; *et al*. *Cálculo Diferencial e Integral de Funções de uma variável com Python*. Rio de Janeiro: Editora Ciência Moderna Ltda., 2019. ISBN: 978-85-399-1037-3.
#
#
# * https://www.sympy.org/en/index.html
# * https://numpy.org/
# * https://matplotlib.org/3.5.3/index.html

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1 - Limite e Continuidade

# %% [markdown]
# ### 1.1 - Definição

# %% [markdown]
# De forma intuitiva, quando falamos da continuidade de uma função $f$ em algum ponto $p$, estamos dizendo que essa função não apresenta "saltos" no seu gráfico.
#
#
# Nas figuras abaixo temos dois exemplos de funções:
# - a do lado esquerdo é dita contínua em $p$;
# - a do lado direito é dita descontínua em $p$.

# %% [markdown]
# ![continuidade.PNG](data:image/png;base64,...)
#
# Retirada do livro Guidorizzi, H. Um curso de cálculo. Vol I.

# %% [markdown]
# **Formalmente temos:**
#
# ---
#
# 1. **Limite**: O limite de uma função $f$ existe se, e só se, $\forall ϵ > 0, \exists δ > 0 $, tal que, se $|x-p|< \delta \Rightarrow |f(x)-f(p)|< \epsilon .$
#
#   Notação:
#
#   $$ \lim_{x \rightarrow p} f(x) = L.$$
#
#   ---
#
# 2. **Continuidade**: Um função $f$ é dita contínua em um ponto $p$, se o limite dessa função existe e é o valor da função no ponto. Ou seja, $L=f(p)$.
#
#   Notação: $$ \lim_{x \rightarrow p} f(x) = f(p).$$
#
#   ---

# %% [markdown]
# ### 1.2 - Aplicação 1
#
# **O problema de aproximação numérica.**

# %% [markdown]
# Dada da função
#
# $$f(x) = \dfrac{2x}{x-2}, $$
#
# analise o que acontece quando $x \to 2$.

# %% [markdown]
# **Tasks:**
#
# * Usar sympy.limit();
#
# https://docs.sympy.org/latest/tutorials/intro-tutorial/calculus.html#limits
# * Usar NumPy para gerar valores x próximos de 2;
# * Plotar o gráfico da função e “dar zoom” no ponto $x=2$.

# %%
# Primeiramente, importe a biblioteca Sympy, e as classes Symbol e Function
import sympy as sp
from sympy import Symbol

# %%
# declare x como variável simbólica

# %%
# construa f(x)

# %% [markdown]
# O método "limit" possibilita verificar a existência do limite de uma função real, passando como argumento a função, a variável da função e o ponto em que se deseja calcular.
#
# Calcule o limite de $f$ quando $x \to 2$.

# %% [markdown]
# Essa função é contínua em $x=2$?

# %%
# dica: use o método "subs" passando como argumento a variável e o ponto em que se deseja avaliar a função

# %% [markdown]
# Use os recursos das bibliotecas Numpy e Matplotlib para gerar o gráfico de $f(x)$ e verifique que essa função não está definida nesse ponto, plotando o gráfico da função.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# contrua uma nova f(x) usando x como um vetor de valores igualmente espaçados



# plote o grafico

# %% [markdown]
# ### 1.3 - Aplicação 2
#
#
# **Sequências limitadas.**

# %% [markdown]
# ---
# Dizemos que uma função é **limitada** se $ \exists \ M > 0$, tal que,
#
# $$|f(x)| \leq M$$
#
# para todo $x \in D_f$.
#
# **Exemplos:**
#
# * As funções contantes ($f(x) = c$) são limitadas;
# * A função $f(x) = \dfrac{1}{x}$, com a restrição $x \in [1, +\infty[$, é limitada (nesse conjunto!) pois
# $$
# 0 \leq f(x) \leq 1.
# $$
#
# ---

# %% [markdown]
# Dada da função
#
# $$g(x) = k \cdot cos( n \pi x  ), $$
#
# com $k \in \mathbb{R}$ e $n \in \mathbb{Z}$, verifique que essa função é limitada.
#
# **Tasks:**
#
# * Verificar como $k$ e $n$ interferem no comportamento (gráfico) de $g$;
# * Calcular os valores máximo e mínimo deo $g$;
# * Deduzir um valor para $M$.

# %% [markdown]
# Comece declarando a função com Sympy.

# %% [markdown]
# Plote o gráfico de $g$ e diga como os parâmetros $k$ e $n$ interferem nessa função.

# %% [markdown]
# Declare a função com Numpy.

# %% [markdown]
# Encontre os valores máximo e mínimo dessa função.
#
# https://numpy.org/doc/2.2/reference/generated/numpy.max.html

# %%
#print("O valor max é ", round(np.max(g), 5), "e o mínimo é", round(np.min(g),5) )

# %% [markdown]
# Estime o valor de $M$ usando um laço para testar possíveis valores para essa constante.
#
# * Lembre de usar o valor absoluto de $g$ nos pontos do domínio ($|g(x)|$).
# https://numpy.org/doc/2.3/reference/generated/numpy.absolute.html
# * Use o máximo desses valores para estimar M.
#
#
# Explicação sobre laços:
#
# https://www.codaqui.dev/trilhas/python/page-3/?gad_source=1&gad_campaignid=23058687337&gbraid=0AAAAAo5uCBaWGIHyR_zZtFcpBOXD3zJNB&gclid=CjwKCAjwgeLHBhBuEiwAL5gNESGQ9kKIa9KLby18d8W5r6W9nvV0AzP7TJ-AIIDUPWUGHWADWSM4axoC6xkQAvD_BwE

# %%
#dica: use laços e condicionais...

# %% [markdown]
# Teste os valores de posições menores e verifique que eles não satisfazem a desigualdade  $|g(x)| \leq M$.

# %%
np.abs( np.max(g)) <= M[10]

# %% [markdown]
# Explicação sobre booleanos:
#
# https://docs.python.org/pt-br/3/c-api/bool.html

# %% [markdown]
# ---

# %% [markdown]
# ## 2 - Derivação

# %% [markdown]
# ### 2.1 - Definição
#
# Considere uma função $f$ que passa por um ponto $p$ fixo, como na figura abaixo. Caso tomemos um outro ponto $x$ e o façamos se aproximar de $p$, o que acontece?
#
# R: Encotramos o limite de $f$ quando $x$ tende a $p$.

# %% [markdown]
# ![derivada.PNG](data:image/png;base64,...)
#
# Retirada do livro Guidorizzi, H. Um curso de cálculo. Vol I.

# %% [markdown]
# Seja $I$ um intervalo aberto não-vazio e seja
# $f : I \to \mathbb{R}$, $y = f(x)$,
# uma função de $I$ em $\mathbb{R}$.
# Diz-se que a função $f(x)$ é derivável no ponto
# $p \in I$ se existir o seguinte limite:
#
# $$f'(p) = \lim_{x \rightarrow p}  \frac{f(x) - f(p)}{x - p},$$
#
#
# Essa expressão representa o quanto a função $f$ varia, a medida que a diferença $x - p \rightarrow 0$. O que chamamos de **taxa de variação** ou **derivada** de f no ponto p.

# %% [markdown]
# ### 2.2 - Aplicação 3
#
# **O problema da reta tangente.**

# %% [markdown]
# Dada da função
#
# $$ x(t) = t^3 - 3t + 2$$
#
# que representa a posição de uma partícula livre em função do tempo $t \in [0, T]$, $T>0$.

# %% [markdown]
# **Tasks:**
#
# * Calcular a expressão para velocidade da partícula, ou seja, $x'(t)$, usando 'sympy.diff()'
#
# https://docs.sympy.org/latest/tutorials/intro-tutorial/calculus.html#derivatives
# * Encontrar a expressão para a reta tangente à curva $x(t)$ no ponto $t_0=2$;
# * Plotar o gráfico de $x(t)$ e da reta tangente.

# %% [markdown]
# **Derivadas**
#
# O método "diff" possibilita o cálculo da expressão geral da derivada de uma função passando como argumento a função a ser derivada e a variável, tantas vezes quanto se queira derivar.

# %% [markdown]
# Declare $t$ como variável e construa $x(t)$.

# %% [markdown]
# Calcule $x'(t)$.

# %%
# chame a derivada de dxdt

# %% [markdown]
# Obtenha a expressão da reta tangente ao ponto $t_0=2$, lembrando que a equação da reta é
#
# $$x - x(t_0) = m ( t - t_0  ).$$

# %%
# dica, use subs() para substituir t por t0 na expressão
# chame a expressao da reta tangente de x_tan

# %% [markdown]
# Plote o gráfico de $x(t)$, $x'(t)$ e $x_{tan}(t)$.

# %% [markdown]
# ---

# %% [markdown]
# ### 2.2 - Aplicação 4
#
# **Derivada pela definição.**

# %% [markdown]
# Dada da função
#
# $$f(x) =\displaystyle  e^{-k x}$$
#
# com $k>0$, calcule $f'(x)$ pela definição.

# %% [markdown]
# **Tasks:**
#
# * Calcular a expressão para velocidade da partícula, ou seja, $x'(t)$, usando 'sympy.diff()'
#
# https://docs.sympy.org/latest/tutorials/intro-tutorial/calculus.html#derivatives
# * Encontrar a expressão para a reta tangente à curva $x(t)$ no ponto $t_0=2$;
# * Plotar o gráfico de $x(t)$ e da reta tangente.

# %% [markdown]
# Declare $x, k$ e $x_0$ como variáveis simbólicas e monte a função $f$.

# %%
# use sp.symbols()
x, k, x0 =

# %% [markdown]
# Defina a expressão
#
# $$  \frac{f(x) - f(x_0)}{x - x_0} .$$

# %%
# lembre de usar parenteses na divisão e use x.subs(x,x0) para trocar x por x0
expressao =

# %% [markdown]
# Defina a derivada como o limite dessa expressao quando $x \to x_0$.

# %%
# chame f' de dfdx

# %% [markdown]
# ---

# %% [markdown]
# ## 3 - Integração

# %% [markdown]
# ### Definições
#
# Considere um subconjunto $I \subset \mathbb{R}$, tal que $I = (a, b)$, onde $a < b$.
#
# Além disso, considere uma partição $P$ desse intervalo de modo que
#
# $$P:= a=x_0 < x_1 < x_2 < … < x_{n-1} < x_n = b. $$
#
# Para cada índice $i$ ($i = 1, 2, 3, …, n$), tomamos pontos $c_i$ dos subintervalos $ [x_{i − 1}, x_i]$, escolhidos arbitrariamente, como mostrado abaixo.

# %% [markdown]
# ![particao.PNG](data:image/png;base64,...)
#
# Retirada do livro Guidorizzi, H. Um curso de cálculo. Vol I.

# %% [markdown]
# Considere também uma função $f$, avaliada em cada ponto $c_i$, ou seja, $f(c_i)$. Visualmente, o que temos são elementos da imagem da função que correspondem a pontos de "altura" relativa a curva gerada pela função $f$. Observe abaixo:

# %% [markdown]
# ![riemann_baixa.jpg](data:image/jpeg;base64,...)
#
# Retirada do livro Carvalhaes, C. G; et al. Cálculo Diferencial e Integral de Funções de uma variável com Python.

# %% [markdown]
# **Soma de Riemann**
#
# Graficamente, quando tomamos o produto $f(c_i) (x_i - x_{i-1}) $, obtemos áreas retagulares que, **quanto menor**  for o subintervalo $\Delta x_i$, **melhor será** a aproximação do valor da área abaixo da curva gerada por $f$.
#
# O valor
# $$ \sum_{i=1} ^{n} f(c_i) \Delta x_i   $$
#
# denomina-se soma de Riemann de f.

# %% [markdown]
# **Integral (de Riemann)**
#
# O que chamamos de integral (segundo Riemann) é o número $L$ (se existir tal número), encontrado quando fazemos o valor máximo dos subintervalos $\Delta x_i$ tenderem a zero. Ou seja,
#
# ![image.png](data:image/png;base64,...)
#
# Ou de forma mais tradicional, se $f$ é integrável em $I = [a, b]$,
#
# ![image.png](data:image/png;base64,...) .
#
#
#
# Imagens retiradas do livro Guidorizzi, H. Um curso de cálculo. Vol I.

# %% [markdown]
# ### Prática
#
# Podemos verificar se as funções que aprendemos a declarar com o Sympy, possuem ou não integral.

# %%
import sympy as sp
from sympy import Symbol, Function

x, f, g = Symbol('x'), Function('f'), Function('g')

# %% [markdown]
# O método "integrate" possibilita o cálculo da expressão geral da integral de Riemann de uma função real, passando como argumento:
# - a variável da função para obter a integral indefinida;
# - a variável da função e intervalo na forma ($x, a, b$).
#
# \\
#
# **Exemplo 1**: Declare as funções $f(x) = \frac{\sqrt{x} }{x^2 - 1}$ e $g(x) = sen(x^3)$ e use o comando
# - "sp.integrate(função, variável)" para achar a integral indefinida de cada função.

# %% [markdown]
# Encontre $\int f(x) dx$

# %%
sp.integrate(f, x)

# %% [markdown]
# Encontre $\int g(x) dx$

# %% [markdown]
# **Exemplo 2**: Usando as mesmas funções, use o comando
# - "sp.integrate(função, (variável, a, b) )" para achar a integral definida de cada função.

# %% [markdown]
# Encontre $\int_a  ^b f(x) dx$

# %%
sp.integrate(f, (x, -1, 1) )

# %% [markdown]
# Encontre $\int_a  ^b g(x) dx$

# %% [markdown]
# #### Propriedades

# %% [markdown]
# **Verifique a validade do teorema abaixo.**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Nessa documentação podemos consultar como declarar vários tipos de funções:
#
# https://numpy.org/doc/stable/reference/routines.math.html

# %%
#a)

# %%
#b)

# %%
#c)

# %%
#d)

# %% [markdown]
# #### Desafio

# %% [markdown]
# **1. Calcule as somas de Riemann das funções abaixo:**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Dica: Use laços e recursos do Numpy!
#
# Podem se basear no exercício (1), já está feito abaixo, para desenvolverem os demais itens.

# %%
#EXECUTE ESSE CÓDIGO MUDANDO APENAS OS ARGUMENTOS "a", "b" E "n" (SE QUISER)!!

import numpy as np
from numpy import sum, linspace

# definindo a partição do intervalo
n = 100
a = -2 #extremo inferior do intervalo
b = 3 #extremo superior do intervalo
x = np.linspace(a, b, n)   #verifique que o intervalo foi dividido em "n" partes


# definindo os pontos ci (nesse caso) médios no intervalo
ci = np.zeros(len(x)-1)

for i in range(len(x)-1):
  ci[i] =  (x[i+1]+x[i]) / 2

# %%
# EXECUTE ESSE CÓDIGO MUDANÇA A EXPRESSÃO DA FUNÇÃO PARA CADA ITEM DO EXERCÍCIO. CONSIDERE OS "ci" COMO "x" DA FUNÇÃO

# a função falculada em ci, a função é f(x) = x**2
f = (ci**4)/4 - ci**3 - 2*ci**2 + 3

# %%
# EXECUTE O CÓDIGO SEM MUDAR NADA!!

# a soma de riemann
somatorio = np.zeros(len(x)-1)

for i in range(len(x)-1):
  somatorio[i] = f[i] * (x[i+1]-x[i])

rieman = sum(somatorio)
float(rieman.round(5))

# %%
# AQUI, PARA CADA ITEM, ALTERE A EXPRESSÃO DA FUNÇÃO

# verificando se a soma é uma boa aproximação, usando as ferramentas padrões do Sympy
x = sp.Symbol('x')
f = sp.Function('f')


f =  (x**4)/4 - x**3 - 2*x**2 + 3
sp.integrate(f, (x, a, b)).evalf().round(5)  #evalf() força o sympy a devolver um número (e não uma fração, por exemplo)
#Verifique que a soma de rieman é uma boa aproximação para a integral!

# %% [markdown]
# ----

# %% [markdown]
# **Lista de presença - Aula 2**
#
# https://forms.gle/2DZyG6cHwBQ5FynS9
#
#  ![presenca_2.png](data:image/png;base64,...)
