# %% [markdown]
# # **Python: Introdução ao Cálculo com uma variável real.**
#
#
# **Instrutor: Samuel Rodrigues**
#
# E-mail: shrodrigues_mat@outlook.com
#
#
#
# ---
#
#
# ##Aula 1
#
#
# https://colab.research.google.com/drive/1N5cq1b3TCgNRlojTW12dvIHYqrDptd9f?usp=drive_link

# %% [markdown]
# ![Aula1PIC.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Conteúdo**
#
# *  **Introdução**: o que é Python, declaração de variáveis numéricas e operações aritméticas;
#
# * **Funções Matemáticas**: biblioteca Sympy, conceitos fundamentais do cálculo, declaração de variáveis e funções matemáticas, operação com funções e plotagem de gráficos.
#
# \\
#
# **Referências:**
#
# * Guidorizzi, H. *Um curso de cálculo.* Vol I. - 5.ed.- Rio de Janeiro: LTC, 2013. ISBN 978-85-216-2244-4.
#
# * Carvalhaes, C. G; *et al*. *Cálculo Diferencial e Integral de Funções de uma variável com Python*. Rio de Janeiro: Editora Ciência Moderna Ltda., 2019. ISBN: 978-85-399-1037-3.
#
# * https://www.sympy.org/en/index.html
#
# * https://numpy.org/doc/stable/reference/routines.math.html

# %% [markdown]
# ## 1 - O que é Python?
#
#
# Python é uma linguagem de programação de uso geral. Isso significa que é uma linguagem que funciona para criar uma grande variedade de aplicações diferentes.
#
# Por ser uma linguagem extremamente versátil e de fácil compreensão, ela se tornou uma das linguagens mais comuns da atualidade, sendo utilizada para diversas finalidades:
#
# * A análise de dados;
# * Machine Learning (aprendizado de máquina);
# * Desenvolvimento web;
# * Automação;
# * Desenvolvimento de app;
# * etc.
#
# \\
# Além disso, aprender essa linguagem pode ser muito vantajoso porque ela:
#
# * Possui uma sintaxe simples;
# * É de código aberto;
# * É versátil;
# * Tem uma comunidade fiel e ativa, o que facilita o aprendizado;
# * É utilizado por grandes empresas, sendo bastante popular na Ciência de Dados;
# * Está em alta no mercado de trabalho.
#
# \\
#
# Baseado no artigo da Alura:
#
# https://www.alura.com.br/artigos/python?srsltid=AfmBOoq5JEDcITo2due9T5-26Ugdnzo21BSPvYJVbpEnqHjtaBqjcv0C

# %% [markdown]
# ## 2 - Aritmética básica
#
# Como essa linguagem pode ajudar no aprendizado da Matemática e contribuir para que cientistas das áreas exatas possam ampliar as suas fronteiras de conhecimento?
#
# R: Ela pode ajudar na resolução de problemas:
# * de aritmética (ex.: contagem);
# * de cálculo diferencial e integral;
# * que envolvam matrizes e suas decomposições;
# * de simulação numérica de equações diferencias (ordinárias, parciais, estocásticas);
# * etc.

# %% [markdown]
# ### Declaração de variáveis

# %% [markdown]
# * **Strings** - caracteres, palavras e textos, que devem ser declarados entre aspas simples ou duplas após o sinal de (=).
#
# **Exemplo** (mais manjado do mundo):
#
# mensagem = 'Olá,  mundo!'
#
# \\
#
# **Obs**.: pode-se fazer comentários escrevendo textos após o 'hashtag' (#)

# %%
# transcreva o exemplo nesssa célula e aperte shift+enter para executar o código

# %%
# para visualizar, é preciso chamar a variável declarada
# escreva o nome dela e aperte shift+enter para executar

# %%
# também podemos usar o comando print(nome_da_variável) para visualizar a frase

# %% [markdown]
# * **Inteiros e floats** - valores numéricos ($\mathbb{Z}$ ou $\mathbb{R}$) que podem facilmente ser declarados usando o sinal de igual (=).
#
# **Exemplo**:
#
# x = 3
#
# y = -4
#
# z = 5.0

# %%
# declare e execute as variáveis acima, pode mudar os valores se quiser.

# %%
# chame alguma variável

# %% [markdown]
# **Tipo**
#
# Para verificar o tipo de variável que estamos trabalhando, utilizamos a função type.
#
# Execute as células abaixo e verifique!

# %%
#str de string
type(mensagem)

# %%
# int de número inteiro
type(x)

# %%
#float de número real
type(z)

# %% [markdown]
# ### Operações aritméticas
#
# Agora, vamos relembrar das aulas de Álgebra I e aprender a manipular variáveis numéricas com Python, **nossa calculadora com esteróides**.
#
#
# Sejam $a, b, c \in \mathbb{R}$ e $n \in \mathbb{Z}_+$, faça o que se pede.

# %% [markdown]
# 1. Atribua valores para as variáveis $a, b, c, n$ de acordo com as restrições acima.

# %% [markdown]
# 2. Efetue as seguintes operações (em células separadas):
#
# * soma (+): a + b
#
# * subtração(-): a - c
#
# * produto(x): a * b
#
# * divisão(/): a / c (se $c \neq 0$)

# %% [markdown]
# 3. Efetue as operações com expressões parentisadas (em células separadas):
#
# * distributiva à direita: (a + b) * c
#
# * distributiva à esquerda: a * (b - c)
#
# * produto misto: (a + b) * (a - b) / (a + c) * (b - c)   $ \  $  (onde $a \neq -c$ e $b \neq c$)

# %% [markdown]
# ## 3 - Sympy e a Matemática Simbólica
#
# Para declarar variáveis simbólicas e funções matemáticas vamos fazer uso de uma biblioteca do Python chamada **Sympy**.
#
# Bibliotecas são **conjuntos de códigos criados para facilitar rotinas ou tarefas específicas**, por exemplo:
#
# * Numpy - para manipulação de vetores e matrizes;
# * Pandas - para manipulação, limpeza e construção de dataframes;
# * Matplotlib - visualização gráfica de funções, datasets, etc.
#
# \\
#
# Baseado no artigo da Hashtag Treinamentos:
#
# https://www.hashtagtreinamentos.com/biblioteca-no-python?gad_source=1&gclid=Cj0KCQjwr9m3BhDHARIsANut04ZRod79c2D7qT3zVWcPTryBYvCpeqp0e62ob0iPXEyJoN3loQ5AnjoaAkA_EALw_wcB

# %% [markdown]
# ![logo_sympy.png](data:image/png;base64,...)
#
#
# "O **SymPy** é uma biblioteca Python para matemática simbólica. Ela tem como objetivo se tornar um sistema de álgebra computacional (CAS) completo, mantendo o código o mais simples possível para ser compreensível e facilmente extensível."
#
# Texto retirado do site:
# https://www.sympy.org/en/index.html

# %% [markdown]
# ### Definições
#
# De forma bem resumida uma função é uma aplicação (relação) entre dois conjuntos $A$ e $B$ chamados de Domínio e Contradomínio, respectivamente, tal que $f$ associa cada elemento $x \in A$ um único elemento $y \in B$, onde $y = f(x)$.
#
# $f: A \longmapsto B$

# %% [markdown]
# ![def_função.png](data:image/png;base64,...)

# %% [markdown]
# É claro que, para uma definição tão geral, podemos ter funções "bonitinhas" como
#
# $f(x) = x$,
#
# mas por outro lado, podemos também "objetos bizarros" como
#
# $\displaystyle  g(x) =\frac{1}{x^{\pi} } e^{sen( ln( x^{tan(x^2)})} $.
#
#
# \\
# Portanto, para cada função que temos em mãos, é necessário um tratamento específico para analisar qual seu **domínio**, **contradomínio**, **imagem**, e também quais seus pontos de **descontinuidade**, sem a função tem ou não **derivada** e **primitiva** (integral).
#
# \\
# A partir de agora, vamos aprender ferramentas do Python para fazer essas análises de forma computacional.

# %% [markdown]
# ### Construindo funções

# %% [markdown]
# Antes de começar vamo importar a biblioteca Sympy para podemos utilizar suas diversas funcionalidades.

# %%
import sympy as sp

# %% [markdown]
# E agora, para declarar variáveis e funções genéricas (ou para se construi-las manualmente) com Sympy utilizamos duas classes: Symbol e Function. É preciso "desempacotar" essas classes, importando do Sympy.

# %%
from sympy import Symbol, Function

# %% [markdown]
# Declaramos as variáveis e funções por meio de strings da seguinte forma:

# %%
# x é uma variável complexa como default, passando o argumento "real=True" ela se torna do tipo real
x = Symbol('x', real=True)

# funções genéricas, para se construir monômios, binômios, polinômios...
f = Function('f')
g = Function('g')

# %% [markdown]
# #### Funções Polinomiais
#
# São funções da forma $f(x) = \sum _{i=0} ^{n} a_i x^i $, onde $n \in \mathbb{N}$ é o **grau** do polinômio, e $a_n \neq 0$.

# %% [markdown]
# **Exemplo**:
#
# Vamos construir as funções $f$ e $g$, tais que
#
# * $f$ tenha grau 1 (função afim), i.e., $f(x) = a_1 x + b_1 $;
#
# * $g$ tenha grau 2 (função quadrática), i.e., $g(x) = a_2 x^2 + b_2 x + c$;
#
# * as constantes $a_i$, $b_i$ e $c$ sejam arbitrárias ($i = 1, 2$).

# %%
a1 = 1
a2 = 2
b1 = -1
b2 = -2
c = 1

f = a1*x + b1
g = a2*x**2 + b2*x + c

# %%
f
# Out:
# x - 1

# %%
g
# Out:
# 2*x**2 - 2*x + 1

# %% [markdown]
# **Raízes**
#
# Podemos calcular as raízes das expressões algébricas "desempacotando" a classe *real_roots* (raízes reais) e *roots* (para raízes complexas).

# %%
from sympy import roots, real_roots
roots(g, x)    #retorna a raiz e a multipliciadade após o ":"
# Out:
# {1/2 - I/2: 1, 1/2 + I/2: 1}

# %%
real_roots(g ,x )   #aqui vemos que nesse caso, essa função não tem raízes reais.
# Out:
# []

# %% [markdown]
# **Operação com funções**
#
# A partir de funções reais, podemos obter outras funções através das operações de soma, subtração, produto e quociente.
#
#
# Sejam $f$ e $g$ duas funções tais que $ D_f \cap D_g$ seja diferente do vazio, definimos os seguintes resultados:
#
# * Soma/Subtração: $(f + g)(x) = f(x) + g(x)$
#
# * Produto: $(f \cdot g)(x) = f(x) \cdot g(x)$
#
# * Quociente: $(\frac{f}{g})(x) = \frac{f(x)}{g(x)}  $,
#
#  tal que $g \neq 0, \forall x D_f \cap D_g$.
#
# Verifique!

# %% [markdown]
# **Soma:**

# %%
soma = f + g
soma
# Out:
# 2*x**2 - x

# %% [markdown]
# **Produto:**

# %%
prod = f * g
prod
# Out:
# (x - 1)*(2*x**2 - 2*x + 1)

# %%
#utilize o método "expand" para desenvolver as expressões, aplicar a distributiva.
prod.expand()      # o código também funciona aplicando sp.expand(prod), verifique!
# Out:
# 2*x**3 - 4*x**2 + 3*x - 1

# %% [markdown]
# **Divisão:**
#
# Obs.: A **divisão de polinômios** recebe um nome especial: **função racional**.

# %%
divi = f/g
divi

## %reset -f   ##ignora isso!!
# Out:
# (x - 1)/(2*x**2 - 2*x + 1)

# %% [markdown]
# ---

# %% [markdown]
# #### Funções Racionais
#
#
# São funções da forma $f(x) = \frac{p(x)}{q(x)}$, onde $p$ e $q$ são funções polinomiais e $q(x) \neq 0$.

# %% [markdown]
# **Exemplo**:
#
# Vamos construir as funções $f$ e $g$, tais que
#
# * $f(x) = \frac{a_1 x + b_1}{a_2 x^2 - b_2}$;
#
# * $g(x) = \sqrt{ \frac{a_1 x}{x - b_2} }$;
#
# * as constantes $a_i$, $b_i$ e $c$ sejam arbitrárias ($i = 1, 2$).

# %%
a1 =
a2 =
b1 =
b2 =
c =

f =
g = sp.sqrt(x)    #para usar raiz quadrada usamos a função sqrt, mas é preciso chama-la do biblioteca!!
# para ser obter uma raiz n-ésima, use sp.sqrt[indice](expressao)

# %%
f

# %%
g

# %% [markdown]
# #### Funções Trigonométricas
#
# São exemplos, as funções:
#
# - seno
# - cosseno
# - tangente
# - secante, cossecante, cotangente, etc.
#
#
# Nessa documentação podemos consultar como declarar a funções trigonométricas (e várias outras):
#
# https://numpy.org/doc/stable/reference/routines.math.html

# %% [markdown]
# Mão na massa! Declare algumas funções trigonométricas!

# %% [markdown]
# ---

# %% [markdown]
# #### Funções Logarítmicas
#
# É o tipo de função que tem a forma $f(x) = \log_a x$, onde $a > 0$ e $a \neq 1$ é chamado de **base** e $x$, é o logaritmando.
#
#
# **Lembrete**: O logaritmo de $x$ na base $a$ é o expoente que se deve atribuir à base a para se obter $x$.
#
#
#
# Mão na massa! Declare algumas funções logarítmicas!

# %%
log_a_x = sp.log(expressao, base)    # log de x, na base "a"

# %%
sp.log(x)     # logartimo natural, ln x
# Out:
# log(x)

# %% [markdown]
# #### Funções Exponenciais
#
# É o tipo de função que tem a forma $f(x) = a^x$, onde $a > 0$ e $a \neq 1$ é chamado de **base** e $x$, **expoente** real.
#
#
# Mão na massa! Declare algumas funções exponenciais!

# %% [markdown]
# **Exemplo**
#
# - $e$ é chamado número de Euler, é uma constante famosa que aparece naturalmente como solução de algumas equações diferenciais.
# - Declare a função de decrescimento $f(x) = e^{-k \cdot x}$, onde $k \in \mathbb{R_+ ^{*}}$.

# %% [markdown]
# ---

# %% [markdown]
# ### Construindo gráficos

# %% [markdown]
# Por definição, o gráfico de uma função $f$, denotado por $G_f$, é o subconjunto do conjunto dos pares ordenados $(x,y)$. Ou seja, e o conjunto de pontos de $\mathbb{R}^2$ (ou $\mathbb{C}^2$), tais que $y=f(x)$. Ou seja,
#
# $Gf = \{ (x,f(x)) \ | \ x \in A \}$.
#
#
# Nessa documentação podemos consultar como aprimorar nossas gráficos:
# https://docs.sympy.org/latest/modules/plotting.html#sympy.plotting.plot.Plot

# %% [markdown]
# **Exemplo**
#
# ![grafico.PNG](data:image/png;base64,...)

# %% [markdown]
# Vamos utilizar a classe "plot" do Sympy, para projetar os gráficos das funções, passando como argumento a expressão da função, a variável em questão e o intervalo desejado.
#
# **Exemplo:** Plote o gráfico da curva $v(t) = t^2 sen (at)  $, onde $a>0$ e $t \in [-10, 10]$.

# %%
# declare a nova variável t e a função v!
a = 1
t = sp.symbols('t')
v = t**2 * sp.sin(a*t)

# %%
# plotando o gráfico
sp.plot(v, (t, -10, 10) )

# %% [markdown]
# É possível "embelezar" o gráfico:
# - incluindo título (title);
# - adicionando rótulo à função (legend + label).
#
# Dessa forma:

# %%
# definindo o titulo e o rotulo com strings
titulo = 'Velocidade da partícula no instante t'
rotulo = ['vel.']

# %%
# adicionando novos argumentos ao código do plot
sp.plot(v, (t, -10, 10),
        legend=True, #para o sympy entender que queremos mostrar essas informações
        label=rotulo,  #define de qual variável (string) "puxar" rótulo da função
        title=titulo)  #define  de qual variável (string) "puxar" título do grafico

# %%
# podemos passar mais de um rótulo, dependendo da quantidade de funções plotadas

titulo = 'Velocidade e tempo quadrático'
rotulo = ['vel.', 't_quad']

sp.plot(v, t**2 -40, (t, -10, 10),  #adicionando a função t**2
        legend=True, #para o sympy entender que queremos mostrar essas informações
        label=rotulo,  #define de qual variável (string) "puxar" rótulo da função
        title=titulo)  #define  de qual variável (string) "puxar" título do grafico

# %% [markdown]
# #### Desafio

# %% [markdown]
# Contrua o gráfico da função de distribuição normal definida como
#
# $$f(x) = \frac{1}{\sigma \sqrt{2 \pi}} e^{ -\frac{1}{2} (\frac{x - \mu}{\sigma}  )^2}$$
#
# onde:
# - $\mu$ é a média da distribuição ou esperança matemática;
# - $\sigma$ é o desvio padrão da distribuição.
#
#
# Considere:
#
# - $x \in [-5, 5]$;
# - $\mu = 0$ e $\sigma = 1$.

# %%
# contrua a função de distribuicao

# %%
# plote o gráfico da função no intervalo estabelecido

# %% [markdown]
# #### Salvando gráficos

# %%
#nomeie seu gráfico com todas as configurações que vc deseja!!
distribuicao_plot = sp.plot(distribuicao, (x, -5, 5), title="Função de distribuição normal", xlabel="x (em metros)", ylabel='F(x)',
        line_color='red', size=[7,5], margin=0.1)

# depois salve
distribuicao_plot.save('distribuicao_plot.png')
